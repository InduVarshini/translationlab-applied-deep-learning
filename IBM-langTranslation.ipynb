# %% [markdown]
# ## Language Translation

# %%
# !pip install pandas
# !pip install numpy
# !pip install ibm_watson
# !pip install PyPDF2
# !pip install python-dotenv
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.1.1)
# Requirement already satisfied: ibm_watson in ./.venv/lib/python3.12/site-packages (8.1.0)
# Requirement already satisfied: requests<3.0,>=2.0 in ./.venv/lib/python3.12/site-packages (from ibm_watson) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./.venv/lib/python3.12/site-packages (from ibm_watson) (2.9.0.post0)
# Requirement already satisfied: websocket-client>=1.1.0 in ./.venv/lib/python3.12/site-packages (from ibm_watson) (1.8.0)
# Requirement already satisfied: ibm-cloud-sdk-core==3.*,>=3.3.6 in ./.venv/lib/python3.12/site-packages (from ibm_watson) (3.20.6)
# Requirement already satisfied: urllib3<3.0.0,>=2.1.0 in ./.venv/lib/python3.12/site-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson) (2.2.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in ./.venv/lib/python3.12/site-packages (from ibm-cloud-sdk-core==3.*,>=3.3.6->ibm_watson) (2.9.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.5.3->ibm_watson) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3.0,>=2.0->ibm_watson) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3.0,>=2.0->ibm_watson) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3.0,>=2.0->ibm_watson) (2024.8.30)
# Requirement already satisfied: PyPDF2 in ./.venv/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.12/site-packages (1.0.1)

# %%
import pandas as pd
import numpy as np
# coding=utf-8
import json
import os

# %%
from ibm_watson import LanguageTranslatorV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
from dotenv import load_dotenv
load_dotenv('.env')
# Out:
# True

# %% [markdown]
# ### Connecting to IBM Watson API and authenticating it using key and service url provided

# %%
IAM_KEY = os.getenv('IAM_KEY')
SERVICE_URL = os.getenv('SERVICE_URL')

# %%
authenticator = IAMAuthenticator(IAM_KEY)
language_translator = LanguageTranslatorV3(
    version='2018-05-01',
    authenticator=authenticator)
language_translator.set_service_url(SERVICE_URL)
# Out:
#             On 10 June 2023, IBM announced the deprecation of the Natural Language Translator service.
#             The service will no longer be available from 8 August 2022. As of 10 June 2024, the service will reach its End of Support
#             date. As of 10 December 2024, the service will be withdrawn entirely and will no longer be
#             available to any customers.

# %% [markdown]
# ### Sample translation to Tamil Language

# %%
translation = language_translator.translate(
    text='Hello, how are you today?',
    model_id='en-ta').get_result()
print(json.dumps(translation, indent=2, ensure_ascii=False))
# Out:
# {
#   "translations": [
#     {
#       "translation": "ஹலோ, நீங்கள் எப்படி இன்று?"
#     }
#   ],
#   "word_count": 8,
#   "character_count": 25
# }

# %% [markdown]
# ### Let's see what all languages does the IBM watson have provision for

# %%
# List identifiable languages
languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "cy",
#       "name": "Welsh"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
#     {
#       "language": "en",
#       "name": "English"
#     },
#     {
#       "language": "eo",
#       "name": "Esperanto"
#     },
#     {
#       "language": "es",
#       "name": "Spanish"
#     },
#     {
#       "language": "et",
#       "name": "Estonian"
#     },
#     {
#       "language": "eu",
#       "name": "Basque"
#     },
#     {
#       "language": "fa",
#       "name": "Persian"
#     },
#     {
#       "language": "fi",
#       "name": "Finnish"
#     },
#     {
#       "language": "fr",
#       "name": "French"
#     },
#     {
#       "language": "ga",
#       "name": "Irish"
#     },
#     {
#       "language": "gu",
#       "name": "Gujarati"
#     },
#     {
#       "language": "he",
#       "name": "Hebrew"
#     },
#     {
#       "language": "hi",
#       "name": "Hindi"
#     },
#     {
#       "language": "hr",
#       "name": "Croatian"
#     },
#     {
#       "language": "ht",
#       "name": "Haitian"
#     },
#     {
#       "language": "hu",
#       "name": "Hungarian"
#     },
#     {
#       "language": "hy",
#       "name": "Armenian"
#     },
#     {
#       "language": "is",
#       "name": "Icelandic"
#     },
#     {
#       "language": "it",
#       "name": "Italian"
#     },
#     {
#       "language": "ja",
#       "name": "Japanese"
#     },
#     {
#       "language": "ka",
#       "name": "Georgian"
#     },
#     {
#       "language": "kk",
#       "name": "Kazakh"
#     },
#     {
#       "language": "km",
#       "name": "Central Khmer"
#     },
#     {
#       "language": "ko",
#       "name": "Korean"
#     },
#     {
#       "language": "ku",
#       "name": "Kurdish"
#     },
#     {
#       "language": "ky",
#       "name": "Kirghiz"
#     },
#     {
#       "language": "lo",
#       "name": "Lao"
#     },
#     {
#       "language": "lt",
#       "name": "Lithuanian"
#     },
#     {
#       "language": "lv",
#       "name": "Latvian"
#     },
#     {
#       "language": "ml",
#       "name": "Malayalam"
#     },
#     {
#       "language": "mn",
#       "name": "Mongolian"
#     },
#     {
#       "language": "mr",
#       "name": "Marathi"
#     },
#     {
#       "language": "ms",
#       "name": "Malay"
#     },
#     {
#       "language": "mt",
#       "name": "Maltese"
#     },
#     {
#       "language": "my",
#       "name": "Burmese"
#     },
#     {
#       "language": "nb",
#       "name": "Norwegian Bokmal"
#     },
#     {
#       "language": "ne",
#       "name": "Nepali"
#     },
#     {
#       "language": "nl",
#       "name": "Dutch"
#     },
#     {
#       "language": "nn",
#       "name": "Norwegian Nynorsk"
#     },
#     {
#       "language": "pa",
#       "name": "Punjabi"
#     },
#     {
#       "language": "pa-PK",
#       "name": "Punjabi (Shahmukhi script, Pakistan)"
#     },
#     {
#       "language": "pl",
#       "name": "Polish"
#     },
#     {
#       "language": "ps",
#       "name": "Pushto"
#     },
#     {
#       "language": "pt",
#       "name": "Portuguese"
#     },
#     {
#       "language": "ro",
#       "name": "Romanian"
#     },
#     {
#       "language": "ru",
#       "name": "Russian"
#     },
#     {
#       "language": "si",
#       "name": "Sinhala"
#     },
#     {
#       "language": "sk",
#       "name": "Slovakian"
#     },
#     {
#       "language": "sl",
#       "name": "Slovenian"
#     },
#     {
#       "language": "so",
#       "name": "Somali"
#     },
#     {
#       "language": "sq",
#       "name": "Albanian"
#     },
#     {
#       "language": "sr",
#       "name": "Serbian"
#     },
#     {
#       "language": "sv",
#       "name": "Swedish"
#     },
#     {
#       "language": "ta",
#       "name": "Tamil"
#     },
#     {
#       "language": "te",
#       "name": "Telugu"
#     },
#     {
#       "language": "th",
#       "name": "Thai"
#     },
#     {
#       "language": "tl",
#       "name": "Tagalog"
#     },
#     {
#       "language": "tr",
#       "name": "Turkish"
#     },
#     {
#       "language": "uk",
#       "name": "Ukrainian"
#     },
#     {
#       "language": "ur",
#       "name": "Urdu"
#     },
#     {
#       "language": "vi",
#       "name": "Vietnamese"
#     },
#     {
#       "language": "zh",
#       "name": "Simplified Chinese"
#     },
#     {
#       "language": "zh-TW",
#       "name": "Traditional Chinese"
#     }
#   ]
# }

# %% [markdown]
# ### Let's identify the language of a provided text
# Here it will provide the confidence of the text belonging to a language

# %%
# # Identify
language = language_translator.identify("J'm appelle Indu").get_result()
print(json.dumps(language, indent=2))
# Out:
# {
#   "languages": [
#     {
#       "language": "fr",
#       "confidence": 0.9508838920268827
#     },
#     {
#       "language": "it",
#       "confidence": 0.02656904610038754
#     },
#     {
#       "language": "en",
#       "confidence": 0.0055847794477802745
#     },
#     {
#       "language": "da",
#       "confidence": 0.0054322701023351355
#     },
#     {
#       "language": "tr",
#       "confidence": 0.002931324186508045
#     },
#     {
#       "language": "mt",
#       "confidence": 0.0025007951265433852
#     },
#     {
#       "language": "nl",
#       "confidence": 0.0011342700788339716
#     },
#     {
#       "language": "nb",
#       "confidence": 0.0008454521579163408
#     },
#     {
#       "language": "et",
#       "confidence": 0.0006524521733303212
#     },
#     {
#       "language": "de",
#       "confidence": 0.000561793541177038
#     },
#     {
#       "language": "af",
#       "confidence": 0.0004298977668060697
#     },
#     {
#       "language": "nn",
#       "confidence": 0.0003763147802362794
#     },
#     {
#       "language": "ro",
#       "confidence": 0.0003305077480246994
#     },
#     {
#       "language": "sv",
#       "confidence": 0.00015722741481034942
#     },
#     {
#       "language": "ms",
#       "confidence": 0.0001472357856750425
#     },
#     {
#       "language": "lt",
#       "confidence": 0.0001409474672500342
#     },
#     {
#       "language": "lv",
#       "confidence": 0.00012544071200572222
#     },
#     {
#       "language": "ht",
#       "confidence": 0.0001221644157137516
#     },
#     {
#       "language": "cs",
#       "confidence": 0.00011978850840958957
#     },
#     {
#       "language": "cy",
#       "confidence": 0.00010237300340145708
#     },
#     {
#       "language": "pt",
#       "confidence": 8.977665614553277e-05
#     },
#     {
#       "language": "sk",
#       "confidence": 8.626229152668294e-05
#     },
#     {
#       "language": "eu",
#       "confidence": 8.46215286091996e-05
#     },
#     {
#       "language": "es",
#       "confidence": 6.970661795892605e-05
#     },
#     {
#       "language": "pl",
#       "confidence": 6.478565248575565e-05
#     },
#     {
#       "language": "fi",
#       "confidence": 5.780794511647118e-05
#     },
#     {
#       "language": "is",
#       "confidence": 5.2733383108588566e-05
#     },
#     {
#       "language": "eo",
#       "confidence": 5.114901615733219e-05
#     },
#     {
#       "language": "az",
#       "confidence": 4.29060418648916e-05
#     },
#     {
#       "language": "ku",
#       "confidence": 3.686081807305537e-05
#     },
#     {
#       "language": "sq",
#       "confidence": 3.1475001585604795e-05
#     },
#     {
#       "language": "so",
#       "confidence": 3.0916383849769326e-05
#     },
#     {
#       "language": "ca",
#       "confidence": 3.0797730730584566e-05
#     },
#     {
#       "language": "tl",
#       "confidence": 2.3592342453205117e-05
#     },
#     {
#       "language": "hr",
#       "confidence": 1.871163980363032e-05
#     },
#     {
#       "language": "hu",
#       "confidence": 1.5181467617056646e-05
#     },
#     {
#       "language": "zh",
#       "confidence": 9.958893449401988e-06
#     },
#     {
#       "language": "zh-TW",
#       "confidence": 8.040730842584711e-06
#     },
#     {
#       "language": "ja",
#       "confidence": 8.031024028868139e-06
#     },
#     {
#       "language": "sl",
#       "confidence": 5.307390976494262e-06
#     },
#     {
#       "language": "ko",
#       "confidence": 3.781288323480847e-06
#     },
#     {
#       "language": "vi",
#       "confidence": 3.7030192075394853e-06
#     },
#     {
#       "language": "ga",
#       "confidence": 3.1452034602018736e-06
#     },
#     {
#       "language": "hi",
#       "confidence": 2.2933677996500793e-06
#     },
#     {
#       "language": "el",
#       "confidence": 2.0738928043937745e-06
#     },
#     {
#       "language": "th",
#       "confidence": 1.553822698276999e-06
#     },
#     {
#       "language": "my",
#       "confidence": 1.2799026336048325e-06
#     },
#     {
#       "language": "sr",
#       "confidence": 1.2705677998032697e-06
#     },
#     {
#       "language": "he",
#       "confidence": 1.1567014278284796e-06
#     },
#     {
#       "language": "mr",
#       "confidence": 9.606783829214754e-07
#     },
#     {
#       "language": "ar",
#       "confidence": 9.580927097855906e-07
#     },
#     {
#       "language": "ur",
#       "confidence": 9.563247242221792e-07
#     },
#     {
#       "language": "lo",
#       "confidence": 9.315079341142001e-07
#     },
#     {
#       "language": "pa-PK",
#       "confidence": 8.316224950832849e-07
#     },
#     {
#       "language": "uk",
#       "confidence": 6.785001285694492e-07
#     },
#     {
#       "language": "mn",
#       "confidence": 6.225293132039544e-07
#     },
#     {
#       "language": "km",
#       "confidence": 5.805307417361068e-07
#     },
#     {
#       "language": "ne",
#       "confidence": 5.233173160305849e-07
#     },
#     {
#       "language": "ml",
#       "confidence": 5.177346254730351e-07
#     },
#     {
#       "language": "bn",
#       "confidence": 4.881010893565164e-07
#     },
#     {
#       "language": "ta",
#       "confidence": 4.639890415918694e-07
#     },
#     {
#       "language": "pa",
#       "confidence": 4.457487101340694e-07
#     },
#     {
#       "language": "te",
#       "confidence": 3.997882821081297e-07
#     },
#     {
#       "language": "be",
#       "confidence": 3.9632706017372845e-07
#     },
#     {
#       "language": "ru",
#       "confidence": 3.8693809321093827e-07
#     },
#     {
#       "language": "ka",
#       "confidence": 3.459924389240043e-07
#     },
#     {
#       "language": "hy",
#       "confidence": 3.3671648466663093e-07
#     },
#     {
#       "language": "kk",
#       "confidence": 3.2813360327651873e-07
#     },
#     {
#       "language": "ps",
#       "confidence": 2.8394628944759e-07
#     },
#     {
#       "language": "fa",
#       "confidence": 2.671314120527441e-07
#     },
#     {
#       "language": "ky",
#       "confidence": 2.5987389285769746e-07
#     },
#     {
#       "language": "gu",
#       "confidence": 2.518546588496482e-07
#     },
#     {
#       "language": "bg",
#       "confidence": 2.481105483877711e-07
#     },
#     {
#       "language": "ba",
#       "confidence": 2.4214599824385096e-07
#     },
#     {
#       "language": "si",
#       "confidence": 2.261512409650979e-07
#     },
#     {
#       "language": "cv",
#       "confidence": 2.1534621832282593e-07
#     }
#   ]
# }

# %% [markdown]
# ### List of language translation models available

# %%
# # List models
models = language_translator.list_models(
     source='en').get_result()
print(json.dumps(models, indent=2))
# Out:
# {
#   "models": [
#     {
#       "model_id": "en-ar",
#       "source": "en",
#       "target": "ar",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ar",
#       "training_log": null
#     },
#     {
#       "model_id": "en-bg",
#       "source": "en",
#       "target": "bg",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-bg",
#       "training_log": null
#     },
#     {
#       "model_id": "en-bn",
#       "source": "en",
#       "target": "bn",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-bn",
#       "training_log": null
#     },
#     {
#       "model_id": "en-bs",
#       "source": "en",
#       "target": "bs",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-bs",
#       "training_log": null
#     },
#     {
#       "model_id": "en-cnr",
#       "source": "en",
#       "target": "cnr",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": false,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-cnr",
#       "training_log": null
#     },
#     {
#       "model_id": "en-cs",
#       "source": "en",
#       "target": "cs",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-cs",
#       "training_log": null
#     },
#     {
#       "model_id": "en-cy",
#       "source": "en",
#       "target": "cy",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-cy",
#       "training_log": null
#     },
#     {
#       "model_id": "en-da",
#       "source": "en",
#       "target": "da",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-da",
#       "training_log": null
#     },
#     {
#       "model_id": "en-de",
#       "source": "en",
#       "target": "de",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-de",
#       "training_log": null
#     },
#     {
#       "model_id": "en-el",
#       "source": "en",
#       "target": "el",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-el",
#       "training_log": null
#     },
#     {
#       "model_id": "en-es",
#       "source": "en",
#       "target": "es",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-es",
#       "training_log": null
#     },
#     {
#       "model_id": "en-et",
#       "source": "en",
#       "target": "et",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-et",
#       "training_log": null
#     },
#     {
#       "model_id": "en-fi",
#       "source": "en",
#       "target": "fi",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-fi",
#       "training_log": null
#     },
#     {
#       "model_id": "en-fr",
#       "source": "en",
#       "target": "fr",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-fr",
#       "training_log": null
#     },
#     {
#       "model_id": "en-fr-CA",
#       "source": "en",
#       "target": "fr-CA",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-fr-CA",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ga",
#       "source": "en",
#       "target": "ga",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ga",
#       "training_log": null
#     },
#     {
#       "model_id": "en-gu",
#       "source": "en",
#       "target": "gu",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-gu",
#       "training_log": null
#     },
#     {
#       "model_id": "en-he",
#       "source": "en",
#       "target": "he",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-he",
#       "training_log": null
#     },
#     {
#       "model_id": "en-hi",
#       "source": "en",
#       "target": "hi",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-hi",
#       "training_log": null
#     },
#     {
#       "model_id": "en-hr",
#       "source": "en",
#       "target": "hr",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-hr",
#       "training_log": null
#     },
#     {
#       "model_id": "en-hu",
#       "source": "en",
#       "target": "hu",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-hu",
#       "training_log": null
#     },
#     {
#       "model_id": "en-id",
#       "source": "en",
#       "target": "id",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-id",
#       "training_log": null
#     },
#     {
#       "model_id": "en-it",
#       "source": "en",
#       "target": "it",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-it",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ja",
#       "source": "en",
#       "target": "ja",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ja",
#       "training_log": null
#     },
#     {
#       "model_id": "en-kn",
#       "source": "en",
#       "target": "kn",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-kn",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ko",
#       "source": "en",
#       "target": "ko",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ko",
#       "training_log": null
#     },
#     {
#       "model_id": "en-lt",
#       "source": "en",
#       "target": "lt",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-lt",
#       "training_log": null
#     },
#     {
#       "model_id": "en-lv",
#       "source": "en",
#       "target": "lv",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-lv",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ml",
#       "source": "en",
#       "target": "ml",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ml",
#       "training_log": null
#     },
#     {
#       "model_id": "en-mr",
#       "source": "en",
#       "target": "mr",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-mr",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ms",
#       "source": "en",
#       "target": "ms",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ms",
#       "training_log": null
#     },
#     {
#       "model_id": "en-mt",
#       "source": "en",
#       "target": "mt",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-mt",
#       "training_log": null
#     },
#     {
#       "model_id": "en-nb",
#       "source": "en",
#       "target": "nb",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-nb",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ne",
#       "source": "en",
#       "target": "ne",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ne",
#       "training_log": null
#     },
#     {
#       "model_id": "en-nl",
#       "source": "en",
#       "target": "nl",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-nl",
#       "training_log": null
#     },
#     {
#       "model_id": "en-pa",
#       "source": "en",
#       "target": "pa",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-pa",
#       "training_log": null
#     },
#     {
#       "model_id": "en-pl",
#       "source": "en",
#       "target": "pl",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-pl",
#       "training_log": null
#     },
#     {
#       "model_id": "en-pt",
#       "source": "en",
#       "target": "pt",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-pt",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ro",
#       "source": "en",
#       "target": "ro",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ro",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ru",
#       "source": "en",
#       "target": "ru",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ru",
#       "training_log": null
#     },
#     {
#       "model_id": "en-si",
#       "source": "en",
#       "target": "si",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-si",
#       "training_log": null
#     },
#     {
#       "model_id": "en-sk",
#       "source": "en",
#       "target": "sk",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-sk",
#       "training_log": null
#     },
#     {
#       "model_id": "en-sl",
#       "source": "en",
#       "target": "sl",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-sl",
#       "training_log": null
#     },
#     {
#       "model_id": "en-sr",
#       "source": "en",
#       "target": "sr",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-sr",
#       "training_log": null
#     },
#     {
#       "model_id": "en-sv",
#       "source": "en",
#       "target": "sv",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-sv",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ta",
#       "source": "en",
#       "target": "ta",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ta",
#       "training_log": null
#     },
#     {
#       "model_id": "en-te",
#       "source": "en",
#       "target": "te",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-te",
#       "training_log": null
#     },
#     {
#       "model_id": "en-th",
#       "source": "en",
#       "target": "th",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-th",
#       "training_log": null
#     },
#     {
#       "model_id": "en-tr",
#       "source": "en",
#       "target": "tr",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-tr",
#       "training_log": null
#     },
#     {
#       "model_id": "en-uk",
#       "source": "en",
#       "target": "uk",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-uk",
#       "training_log": null
#     },
#     {
#       "model_id": "en-ur",
#       "source": "en",
#       "target": "ur",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-ur",
#       "training_log": null
#     },
#     {
#       "model_id": "en-vi",
#       "source": "en",
#       "target": "vi",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-vi",
#       "training_log": null
#     },
#     {
#       "model_id": "en-zh",
#       "source": "en",
#       "target": "zh",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-zh",
#       "training_log": null
#     },
#     {
#       "model_id": "en-zh-TW",
#       "source": "en",
#       "target": "zh-TW",
#       "base_model_id": "",
#       "domain": "general",
#       "customizable": true,
#       "default_model": true,
#       "owner": "",
#       "status": "available",
#       "name": "en-zh-TW",
#       "training_log": null
#     }
#   ]
# }

# %%
# # Create model
# with open('glossary.tmx', 'rb') as glossary:
#     response = language_translator.create_model(
#         base_model_id='en-es',
#         name='custom-english-to-spanish',
#         forced_glossary=glossary).get_result()
#     print(json.dumps(response, indent=2))

# # Delete model
# response = language_translator.delete_model(model_id='<YOUR MODEL ID>').get_result()
# print(json.dumps(response, indent=2))

# # Get model details
# model = language_translator.get_model(model_id='<YOUR MODEL ID>').get_result()
# print(json.dumps(model, indent=2))

# %% [markdown]
# ## Translation Lab for an art piece description

# %%
#### Document Translation ####
# List Documents that have been submitted for translation
result = language_translator.list_documents().get_result()
print(json.dumps(result, indent=2))
# Out:
# {
#   "documents": [
#     {
#       "document_id": "570bcb90-6e63-4b32-b0fa-3cb114fbd652",
#       "filename": "_content_Hollis_Sigler.pdf",
#       "model_id": "en-te",
#       "source": "en",
#       "target": "te",
#       "status": "available",
#       "created": "2024-09-06T22:56:35Z",
#       "completed": "2024-09-06T22:56:39Z",
#       "word_count": 72,
#       "character_count": 455
#     },
#     {
#       "document_id": "b196d73e-22b0-47b0-ae30-70036ee9434f",
#       "filename": "_content_Hollis_Sigler.pdf",
#       "model_id": "en-es",
#       "source": "en",
#       "target": "es",
#       "status": "available",
#       "created": "2024-09-06T22:58:03Z",
#       "completed": "2024-09-06T22:58:05Z",
#       "word_count": 72,
#       "character_count": 455
#     },
#     {
#       "document_id": "f39b0389-1494-4d4b-a43f-7865a06fc483",
#       "filename": "._constitution.pdf",
#       "model_id": "en-ta",
#       "source": "en",
#       "target": "ta",
#       "status": "available",
#       "created": "2024-09-09T17:03:23Z",
#       "completed": "2024-09-09T17:04:21Z",
#       "word_count": 9308,
#       "character_count": 51316
#     },
#     {
#       "document_id": "1402da76-c956-4fcc-a00c-34aef1718d6f",
#       "filename": "._input_docs_art-1-description.pdf",
#       "model_id": "en-fr",
#       "source": "en",
#       "target": "fr",
#       "status": "failed",
#       "created": "2024-09-09T17:23:00Z",
#       "completed": "2024-09-09T17:23:06Z"
#     },
#     {
#       "document_id": "e1652b31-7e8a-4dcb-a666-44edfc1af3b7",
#       "filename": "_content_Art1.pdf",
#       "model_id": "en-te",
#       "source": "en",
#       "target": "te",
#       "status": "failed",
#       "created": "2024-09-06T22:51:33Z",
#       "completed": "2024-09-06T22:51:34Z"
#     },
#     {
#       "document_id": "78643102-d25d-466d-9e97-31977ce9bef6",
#       "filename": "_content_Hollis_Sigler.pdf",
#       "model_id": "en-hi",
#       "source": "en",
#       "target": "hi",
#       "status": "available",
#       "created": "2024-09-06T23:05:20Z",
#       "completed": "2024-09-06T23:05:23Z",
#       "word_count": 72,
#       "character_count": 455
#     },
#     {
#       "document_id": "cc5a7a6b-b5d6-4cfa-b2ae-e2b754500a13",
#       "filename": "D__YT_YTpaper_insiderinformedcyber_GPU_deep5350_detected_text1.txt",
#       "model_id": "en-zh",
#       "source": "en",
#       "target": "zh",
#       "status": "available",
#       "created": "2024-09-08T20:57:52Z",
#       "completed": "2024-09-08T20:57:54Z",
#       "word_count": 149,
#       "character_count": 937
#     },
#     {
#       "document_id": "3c003420-6cb7-4731-b5b0-24f18474228f",
#       "filename": "._constitution.pdf",
#       "model_id": "en-fr",
#       "source": "en",
#       "target": "fr",
#       "status": "available",
#       "created": "2024-09-03T20:39:03Z",
#       "completed": "2024-09-03T20:39:34Z",
#       "word_count": 9308,
#       "character_count": 51316
#     },
#     {
#       "document_id": "bd71fb0f-98fc-4bcd-8dd5-54d513c136fd",
#       "filename": "._constitution.pdf",
#       "model_id": "en-fr",
#       "source": "en",
#       "target": "fr",
#       "status": "available",
#       "created": "2024-09-03T20:41:21Z",
#       "completed": "2024-09-03T20:41:54Z",
#       "word_count": 9308,
#       "character_count": 51316
#     }
#   ]
# }

# %% [markdown]
# ### Translate the document provided to FRENCH

# %%
# Translate Document
SOURCE_FILE = './input_docs/art1-description.pdf'
#Translating to French
with open(SOURCE_FILE, 'rb') as file:
    result = language_translator.translate_document(
        file=file,
        file_content_type='application/pdf',
        filename=SOURCE_FILE,
        model_id='en-fr').get_result()
    print(json.dumps(result, indent=2))
# Out:
# {
#   "document_id": "f63010e0-170f-4d2a-89d1-82d913357162",
#   "filename": "._input_docs_art1-description.pdf",
#   "model_id": "en-fr",
#   "source": "en",
#   "target": "fr",
#   "status": "processing",
#   "created": "2024-09-09T20:20:58Z"
# }

# %%
# Document Status Check
DOCUMENT_ID = result['document_id']
result = language_translator.get_document_status(
    document_id=DOCUMENT_ID).get_result()
print(json.dumps(result, indent=2))
# Out:
# {
#   "document_id": "f63010e0-170f-4d2a-89d1-82d913357162",
#   "filename": "._input_docs_art1-description.pdf",
#   "model_id": "en-fr",
#   "source": "en",
#   "target": "fr",
#   "status": "available",
#   "created": "2024-09-09T20:20:58Z",
#   "completed": "2024-09-09T20:21:00Z",
#   "word_count": 172,
#   "character_count": 1014
# }

# %%
# Translated Document
with open('translated.pdf', 'wb') as f:
    result = language_translator.get_translated_document(
        document_id=DOCUMENT_ID,
        accept='application/pdf').get_result()
    f.write(result.content)

# %%
# Delete Document
language_translator.delete_document(document_id=DOCUMENT_ID)

# %% [markdown]
# ### Translate the document provided to TAMIL

# %%
#Translating to Tamil
with open(SOURCE_FILE, 'rb') as file:
    result = language_translator.translate_document(
        file=file,
        file_content_type='application/pdf',
        filename=SOURCE_FILE,
        model_id='en-ta').get_result()
    print(json.dumps(result, indent=2))
# Out:
# {
#   "document_id": "342c6a43-53d4-4a35-a92b-55b6f6569bb9",
#   "filename": "._input_docs_art1-description.pdf",
#   "model_id": "en-ta",
#   "source": "en",
#   "target": "ta",
#   "status": "processing",
#   "created": "2024-09-09T20:22:21Z"
# }

# %%
# Document Status Check
DOCUMENT_ID = result['document_id']
result = language_translator.get_document_status(
    document_id=DOCUMENT_ID).get_result()
print(json.dumps(result, indent=2))
# Out:
# {
#   "document_id": "342c6a43-53d4-4a35-a92b-55b6f6569bb9",
#   "filename": "._input_docs_art1-description.pdf",
#   "model_id": "en-ta",
#   "source": "en",
#   "target": "ta",
#   "status": "available",
#   "created": "2024-09-09T20:22:21Z",
#   "completed": "2024-09-09T20:22:27Z",
#   "word_count": 172,
#   "character_count": 1014
# }

# %%
# Translated Document
with open('translated_tamil.pdf', 'wb') as f:
    result = language_translator.get_translated_document(
        document_id=DOCUMENT_ID,
        accept='application/pdf').get_result()
    f.write(result.content)

# %% [markdown]
# References:
# 1. https://watson-developer-cloud.github.io/swift-sdk/services/LanguageTranslatorV3/Classes/LanguageTranslator.html#/s:20LanguageTranslatorV30aB0C13listDocuments7headers17completionHandlerySDyS2SGSg_y15IBMSwiftSDKCore12RestResponseVyAA12DocumentListVGSg_AI0K5ErrorOSgtctF

# %% [markdown]
# ### The above code didn't quite translate the entire text. Let's see if this is because of the PDF format. We will send the plain text to translate.

# %%
# Translate text
text = '''Joan Snyder. 
Born 1940, Highland Park, New Jersey, currently resides in New York. 
Things Have Tears and We Know Suffering. 
1983-1984. Woodcut with oil paint on paper. Gift of Polly and Mark Addison to the Polly and Mark Addison. 
Collection, 91.04.75. In her woodcuts, Snyder layers complex surfaces, symbols, and text to express emotion. 
In the bottom right corner, a figure suckles an elongated breast dotted with patches of grey and purple flesh. 
Just above, Snyder chiseled a stick figure, an icon she used to symbolize the suffering of children. 
Marring the surface of the wood block, gouged lines create the sensation of the print itself shedding tears. 
Carved between the linework is a phrase from Ancient Roman poet Virgil's Aeneid that roughly translates to the title of this image: 
"things have tears and we know suffering." 
Through these layers, Snyder creates a narrative of childhood pain. She suggests the passing of wounds from parents to children, 
communicating a story of generational trauma, memory, and loss.'''

try:
    translation_result = language_translator.translate(
        text=text,
        model_id='en-ta'  # Ensure this is the correct model ID
    ).get_result()

    # Extract the translation only
    translation = translation_result['translations'][0]['translation']

    # Write the translation to a file
    with open('translation_output_tamil.txt', 'w', encoding='utf-8') as file:
        file.write(translation)
        print("Translation written to 'translation_output_tamil.txt'")

except Exception as e:
    print(f"Error during translation: {e}")
# Out:
# Translation written to 'translation_output_tamil.txt'
